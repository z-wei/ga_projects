# %% [markdown]
# <em><center>PROBLEM STATEMENT:</em></center>
# >Advertiser Raw that has not been cleaned and mapped is defined as Unclassified. The objective is to use the Raw Advertiser, campaign and country information to map the Raw field to its correct Advertiser name, Sector 1 and 2. Look for patterns in the data already mapped to a brand and aim to develop a script that automates the process.

# %%
    ###IMPORT###
    
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#### stats
import scipy.stats as stats
#scikitlearn
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score 

    ###DROP, INSPECT, EDIT###
    
#read file
df = pd.read_excel('./BAIS2018.xlsx', sheet_name='BAIS2018')

#drop irrelevant columns
droplist = ['Date','Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Raw fields', 'Advertiser Sector 1', 
           'Platform']
df.drop(droplist, axis=1, inplace=True)

#basic inspection
print('shape : ', df.shape)
print('='*20) 
print('number of unclassified rows : ', len(df[df['Advertiser'] == 'Unclassified']))
print('='*20)
print('number of classified rows : ', len(df[df['Advertiser'] != 'Unclassified' ]))
print('='*20)
df = df[df['Advertiser'] != 'Unclassified' ]

#make all text lowercase
dfcolnames = ['Target Country', 'Campaign', 'Advertiser Raw', 'Advertiser',
       'Advertiser Sector 2']
df = df[dfcolnames].apply(lambda x: x.str.lower())
# Out:
# shape :  (6338, 5)
# ====================
# number of unclassified rows :  316
# ====================
# number of classified rows :  6022
# ====================

# %% [markdown]
# ## PART I - USING ONLY ONE COLUMN TO PREDICT

# %% [markdown]
# #### Advertiser

# %%
    ###SET UP###

#set up
ad = df[['Advertiser Raw', 'Advertiser']].copy()
adcolnames = ['Advertiser Raw', 'Advertiser']

#remove punctuation
import string
translator = str.maketrans(string.punctuation, ' '*len(string.punctuation)) #map punctuation to space
ad['Advertiser Raw'] = ad['Advertiser Raw'].apply(lambda x : x.translate(translator))

#filter categories that have less than 1 data point
filtered = ad.groupby('Advertiser')['Advertiser'].filter(lambda x: len(x) > 1)
ad = ad[ad['Advertiser'].isin(filtered)]

    ###TRAIN TEST###
    
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier

X = ad['Advertiser Raw']
y = ad['Advertiser']

#initialize model
forest = RandomForestClassifier()
logit = LogisticRegression()
cv = CountVectorizer()
X_1 = cv.fit_transform(X)

#train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_1.toarray(), y, random_state=1, test_size=0.2, stratify=y)

#forest
forest.fit(X_train, y_train)
print('forest score is : ', forest.score(X_test, y_test))

#logistic regression
logit.fit(X_train, y_train)
print('logit score is : ', logit.score(X_test, y_test))
# Out:
# forest score is :  0.9958402662229617
# logit score is :  0.9916805324459235

# %%
checkad = pd.DataFrame(data=[forest.predict(X_test), y_test], index=['predict', 'actual']).T
checkad[checkad['predict'] != checkad['actual']]
# Out:
#      predict      actual
# 332     mini         bmw
# 337  porsche     bentley
# 637    acura  land rover
# 809     mini         bmw
# 931    acura  land rover

# %% [markdown]
# #### Advertiser Sector 2

# %%
ad2 = df[['Advertiser Raw', 'Advertiser Sector 2']].copy()
ad2colnames = ['Advertiser Raw', 'Advertiser Sector 2']
ad2 = ad2[ad2colnames].apply(lambda x: x.str.lower())

import string
translator = str.maketrans(string.punctuation, ' '*len(string.punctuation)) #map punctuation to space
ad2['Advertiser Raw'] = ad2['Advertiser Raw'].apply(lambda x : x.translate(translator))

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier

X = ad2['Advertiser Raw']
y = ad2['Advertiser Sector 2']

#initialize model
forest = RandomForestClassifier()
logit = LogisticRegression()
cv = CountVectorizer()
X_1 = cv.fit_transform(X)

#train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_1.toarray(), y, random_state=1, test_size=0.2, stratify=y)

#forest
forest.fit(X_train, y_train)
print('forest score is : ', forest.score(X_test, y_test))

#logistic regression
logit.fit(X_train, y_train)
print('logit score is : ', logit.score(X_test, y_test))
# Out:
# forest score is :  0.995850622406639
# logit score is :  0.9867219917012449

# %% [markdown]
# #### checking on the wrong predictors

# %%
checkad2 = pd.DataFrame(data=[forest.predict(X_test), y_test], index=['predict', 'actual']).T
checkad2[checkad2['predict'] != checkad2['actual']]
# Out:
#                  predict               actual
# 488  commercial vehicles           auto parts
# 498  commercial vehicles   automotive general
# 587  commercial vehicles           auto parts
# 911     auto dealerships  commercial vehicles
# 972  commercial vehicles           auto parts

# %% [markdown]
# ## PART II - USING MULTIPLE COLUMNS TO PREDICT

# %% [markdown]
# #### Set up

# %%
###IMPORT###
    
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#stats
import scipy.stats as stats
#scikitlearn
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score 

    ###DATA CLEANING###

df = pd.read_excel('./BAIS2018.xlsx', sheet_name='BAIS2018')
dfcolnames = ['Target Country', 'Campaign', 'Advertiser Raw', 'Advertiser',
       'Advertiser Sector 2']
df = df[df['Advertiser'] != 'Unclassified' ]
df = df[dfcolnames].apply(lambda x: x.str.lower())

import string
translator = str.maketrans(string.punctuation, ' '*len(string.punctuation)) #map punctuation to space
df = df[dfcolnames].applymap(lambda x : x.translate(translator)) #https://chrisalbon.com/python/data_wrangling/pandas_apply_operations_to_dataframes/

# %% [markdown]
# #### Advertiser

# %%
    ###SET UP###

#include only categories that have more than a value count of one
adcolnames = ['Target Country', 'Campaign', 'Advertiser Raw', 'Advertiser']
filtered = ad.groupby('Advertiser')['Advertiser'].filter(lambda x: len(x) > 1)
ad = df[adcolnames]
ad = ad[ad['Advertiser'].isin(filtered)]

#predictor and target column names
predictors = ['Target Country', 'Campaign', 'Advertiser Raw']
target = ['Advertiser']

# %%
def combine_text_columns(data_frame, to_drop=target):
    """ converts all text in each row of data_frame to single vector """
    
    # Drop non-text columns that are in the df
    to_drop = set(to_drop) & set(data_frame.columns.tolist())
    text_data = data_frame.drop(to_drop, axis=1)
    
    # Replace nans with blanks
    text_data.fillna("", inplace=True)
    
    # Join all text items in a row that have a space in between
    return text_data.apply(lambda x: " ".join(x), axis=1)

# %%
    ###TRAIN TEST##
    
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier

X = combine_text_columns(ad[predictors])
y = ad[target].values.ravel() # interesting why i need to ravel if not I'll get an error msg.

#initialize model
forest = RandomForestClassifier()
logit = LogisticRegression()
cv = CountVectorizer()
X_1 = cv.fit_transform(X)

#train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_1.toarray(), y, random_state=1, test_size=0.2, stratify=y)

#forest
forest.fit(X_train, y_train)
print('forest score is : ', forest.score(X_test, y_test))

#logistic regression
logit.fit(X_train, y_train)
print('logit score is : ', logit.score(X_test, y_test))
# Out:
# forest score is :  0.9874686716791979
# logit score is :  0.9941520467836257

# %%
checkad = pd.DataFrame(data=[forest.predict(X_test), y_test], index=['predict', 'actual']).T
checkad[checkad['predict'] != checkad['actual']]
# Out:
#               predict                actual
# 0           carsguide            bombardier
# 38           cadillac                nissan
# 60            bentley               porsche
# 100             goget           continental
# 142   napa auto parts                carmax
# 145           hyundai              bob jane
# 491            nissan                  seat
# 617            nissan            mitsubishi
# 626            subaru  solitaire automotive
# 1020            goget               hyundai
# 1053           nissan                  seat
# 1113             mini                   bmw
# 1147         goodyear       supercheap auto
# 1148            goget           continental
# 1150              bmw                  mini

# %% [markdown]
# #### advertiser sector 2

# %%
    ###SET UP###
    
ad2colnames = ['Target Country', 'Campaign', 'Advertiser Raw', 'Advertiser Sector 2']
ad2 = df[ad2colnames]
predictors = ['Target Country', 'Campaign', 'Advertiser Raw']
target = ['Advertiser Sector 2']


    ###TRAIN TEST###
    
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier

X = combine_text_columns(ad2[predictors])
y = ad2[target].values.ravel() # interesting why i need to ravel if not I'll get an error msg.

#initialize model
forest = RandomForestClassifier()
logit = LogisticRegression()
cv = CountVectorizer()

X_1 = cv.fit_transform(X)

#train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_1.toarray(), y, random_state=1, test_size=0.2, stratify=y)

#forest
forest.fit(X_train, y_train)
print('forest score is : ', forest.score(X_test, y_test))

#logistic regression
logit.fit(X_train, y_train)
print('logit score is : ', logit.score(X_test, y_test))
# Out:
# forest score is :  0.9933609958506224
# logit score is :  0.995850622406639

# %%
checka2 = pd.DataFrame(data=[forest.predict(X_test), y_test], index=['predict', 'actual']).T
checkad2[checkad2['predict'] != checkad2['actual']]
# Out:
#                  predict               actual
# 488  commercial vehicles           auto parts
# 498  commercial vehicles   automotive general
# 587  commercial vehicles           auto parts
# 911     auto dealerships  commercial vehicles
# 972  commercial vehicles           auto parts

# %% [markdown]
# ## PART III - PREDICTING THE UNCLASSIFIED

# %%
    ###IMPORT###
    
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#stats
import scipy.stats as stats
#scikitlearn
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score 
    
    ###SET UP###
    
#read and basic edit
df = pd.read_excel('./BAIS2018.xlsx', sheet_name='BAIS2018')
droplist = ['Date','Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Raw fields', 'Advertiser Sector 1', 
           'Platform']
df.drop(droplist, axis=1, inplace=True)

#string lower on df
dfcolnames = ['Target Country', 'Campaign', 'Advertiser Raw', 'Advertiser',
       'Advertiser Sector 2']
df = df[dfcolnames].apply(lambda x: x.str.lower())
import string
translator = str.maketrans(string.punctuation, ' '*len(string.punctuation)) #map punctuation to space
df = df[dfcolnames].applymap(lambda x : x.translate(translator))

#split df into classified and unclassified
unclassified = df[df['Advertiser'] == 'unclassified'].copy()
classified = df[df['Advertiser'] != 'unclassified' ]

# %% [markdown]
# #### model 1: Advertiser

# %%
    ###SET UP###
    
#subset dataframe
adcolnames = ['Target Country', 'Campaign', 'Advertiser Raw', 'Advertiser']
ad = classified[adcolnames]

#predictor and target column names
predictors = ['Target Country', 'Campaign', 'Advertiser Raw']
target = ['Advertiser']

    ###IMPORT###
    
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier

    ###CLASSIFIED SECTION###
    
CV = CountVectorizer()
X_train = CV.fit_transform(combine_text_columns(ad[predictors])) #cv.fit_transform ouputs a numpy array
y_train = ad[target].values.ravel() #.ravel to get 1D if not  error msg will result

    ###UNCLASSIFIED SECTION###
    
unclassified_X = unclassified[['Target Country', 'Campaign', 'Advertiser Raw']].copy()
unclassified_X = CV.transform(combine_text_columns(unclassified_X))

logit = LogisticRegression()
logit.fit(X_train, y_train)
predictadvertiser = logit.predict(unclassified_X)
    
    ###ADD TO UNCLASSIFIED DATAFRAME###
    
unclassified['Advertiser'] = predictadvertiser

# %% [markdown]
# #### model 2: Advertiser Sector 2

# %%
    ###SET UP###
    
#subset dataframe
adsec2_colnames = ['Target Country', 'Campaign', 'Advertiser Raw', 'Advertiser Sector 2']
adsec2 = classified[adsec2_colnames]

#predictor and target column names
predictors = ['Target Country', 'Campaign', 'Advertiser Raw']
target = ['Advertiser Sector 2']

    ###IMPORT###
    
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier

    ###CLASSIFIED SECTION###
    
CV = CountVectorizer()
X_train = CV.fit_transform(combine_text_columns(adsec2[predictors])) #cv.fit_transform ouputs a numpy array
y_train = adsec2[target].values.ravel() #.ravel to get 1D if not  error msg will result

    ###UNCLASSIFIED SECTION###
    
unclassified_X = unclassified[['Target Country', 'Campaign', 'Advertiser Raw']].copy()
unclassified_X = CV.transform(combine_text_columns(unclassified_X))

logit = LogisticRegression()
logit.fit(X_train, y_train)
predictadsec2 = logit.predict(unclassified_X)
    
    ###ADD TO UNCLASSIFIED DATAFRAME###
    
unclassified['Advertiser Sector 2'] = predictadsec2
unclassified_predicted = unclassified
unclassified_predicted
# Out:
#       Target Country                                           Campaign  \
# 55    united kingdom  nissan aftersales   dvla data   ret   mobile  ...
# 65    united kingdom                     nissan lcv   eyeota  10313084
# 97           denmark                 interdan leasing q1 bt high income
# 113          germany                   eyeota interest auto enthusiasts
# 115          germany  mercedesbenz pro topdealrange channel news dat...
# 152   united kingdom  lexus int pro 3rd party data ad ctr mixed rtb ...
# 155   united kingdom  mercedes pro 3rd party ad ctr eyeota experian ...
# 168   united kingdom            ppg omp dev  tab  bhv  exp  car age 3 7
# 175   united kingdom  toyota uk pro 3rd party ad cpa multi rtb inter...
# 212    united states  hd 2016 core endemic always on 2016 dsk pro bt...
# 254        australia                                           kia   au
# 274    united states                                   cobalt scr chevy
# 280    united states                                              dodge
# 282    united states                                   honda of fishers
# 291      netherlands                                               ford
# 301    united states  harley davidson buell motorcycles of appleton ...
# 338        australia                              vw das welt auto 2016
# 358   united kingdom              dvla competitor lf    pmp   11845007
# 399        australia                   astra march helix ron 0000028375
# 426        australia                                      mowers p40 54
# 464          germany                                    3rd party dacia
# 541   united kingdom  lexus int pro 3rd party data ad ctr mixed rtb ...
# 551   united kingdom  lexus int pro 3rd party data ad ctr mixed rtb ...
# 569   united kingdom  lexus int pro 3rd party data ad ctr mixed rtb ...
# 581   united kingdom  mercedes benz pro 3rd party ad ctr multi multi...
# 592   united kingdom                 renault clio   be moved   audience
# 610    united states  2016 fco malibu bt  services   business servic...
# 650    united states                                                lal
# 654    united states                           us standard preroll data
# 657   czech republic                                          jaguar cz
# ...              ...                                                ...
# 5846         austria                                          opel  dcm
# 5853          canada                                    gm buick canada
# 5870         germany                                            porsche
# 5888        suriname                                           sr   bmw
# 5893  united kingdom                             citroen c range retail
# 5900  united kingdom                                   toyota uk zenith
# 5905   united states                                      bentley   usa
# 5921   united states                                              honda
# 5952       australia        kia   picanto run out   display prospecting
# 5982  united kingdom      1583 kia sportage q4   oct   dec 16 billboard
# 6020   united states  2016 q1   hispanic core make good   mobile vid...
# 6031   united states  2016 q2q4   hispanic supp   pre roll   san fra...
# 6036   united states  8421 4q fy17 pro upm billing ac bcmp lcl all h...
# 6063   united states  o j01s chevy in market commercial vehicles gum...
# 6081       australia                 hyundai oct16 dec16 prospecting q4
# 6117           italy        it cmt triumph  bobber launch banner oct 16
# 6128  united kingdom         1616 hyundai  range  oct   dec 16   mobile
# 6133  united kingdom            1628 hyundai  tucson  nov  dec 16   vod
# 6137  united kingdom  1694 standard ads   opel astra  dealers    dec 16
# 6146   united states                                          da81 209
# 6152   united states                                          sa78 210
# 6195   united states  triumph motorcycles   us   bmw ducati triumph ...
# 6203   united states  triumph motorcycles   us   d   d cycles  inc  ...
# 6252   united states   triumph motorcycles   us   munroe motors  33197
# 6261   united states  triumph motorcycles   us   redline performance...
# 6270   united states  triumph motorcycles   us   south bay motorspor...
# 6280   united states  triumph motorcycles   us   team winnebagoland ...
# 6290   united states  triumph motorcycles   us   triumph concord  33...
# 6300   united states  triumph motorcycles   us   triumph motorcycles...
# 6310   united states  triumph motorcycles   us   triumph of harrison...
#
#                                          Advertiser Raw           Advertiser  \
# 55                                               nissan               nissan
# 65                                               nissan               nissan
# 97                                        dk mitsubishi           mitsubishi
# 113                        citroen de   full dfa   2015              citroen
# 115                                mercedesbenz de fuel        mercedes benz
# 152   lexus pan euro uk zenith international dcm parent                lexus
# 155                       mercedes benz uk zenith ninah        mercedes benz
# 168                                                 bmw                  bmw
# 175                                    toyota uk zenith               toyota
# 212                          harley davidson us starcom      harley davidson
# 254                                             kia  au                  kia
# 274                                    cobalt scr chevy            chevrolet
# 280                                               dodge                dodge
# 282                                    honda of fishers     honda of fishers
# 291                                                ford                 ford
# 301   harley davidson buell motorcycles of appleton ...      harley davidson
# 338                                    vw das welt auto           volkswagen
# 358                                            infiniti             infiniti
# 399                          holden au   partner select               holden
# 426                                              kubota               kubota
# 464                                    dacia  dfa zero                 dacia
# 541   lexus pan euro uk zenith international dcm parent                lexus
# 551   lexus pan euro uk zenith international dcm parent                lexus
# 569   lexus pan euro uk zenith international dcm parent                lexus
# 581                       mercedes benz uk zenith ninah        mercedes benz
# 592                                             renault              renault
# 610                  gm fleet and commercial operations       general motors
# 650                                       maserati umdt            chevrolet
# 654                                 triumph motorcycles  triumph motorcycles
# 657                                           jaguar cz               jaguar
# ...                                                 ...                  ...
# 5846                                          opel  dcm                 opel
# 5853                                    gm buick canada                buick
# 5870                                            porsche              porsche
# 5888                                           sr   bmw                  bmw
# 5893                             citroen c range retail              citroen
# 5900                                   toyota uk zenith               toyota
# 5905                                      bentley   usa              bentley
# 5921                                              honda                honda
# 5952                                         kia motors                  kia
# 5982                                  havas media   kia                  kia
# 6020                                 q11   honda norcal                honda
# 6031                                 q11   honda norcal                honda
# 6036                                             carmax               carmax
# 6063                                           gm chevy            chevrolet
# 6081                                       hyundai   au              hyundai
# 6117                                triumph motorcycles  triumph motorcycles
# 6128                              havas media   hyundai              hyundai
# 6133                              havas media   hyundai              hyundai
# 6137                                       carat   opel                 opel
# 6146            toyota     davis elen  los angeles  us                toyota
# 6152                       toyota     saatchi   saatchi               toyota
# 6195                       accuen   triumph motorcycles  triumph motorcycles
# 6203                       accuen   triumph motorcycles  triumph motorcycles
# 6252                       accuen   triumph motorcycles  triumph motorcycles
# 6261                       accuen   triumph motorcycles  triumph motorcycles
# 6270                       accuen   triumph motorcycles  triumph motorcycles
# 6280                       accuen   triumph motorcycles  triumph motorcycles
# 6290                       accuen   triumph motorcycles  triumph motorcycles
# 6300                       accuen   triumph motorcycles  triumph motorcycles
# 6310                       accuen   triumph motorcycles  triumph motorcycles
#
#         Advertiser Sector 2
# 55      commercial vehicles
# 65      commercial vehicles
# 97      commercial vehicles
# 113     commercial vehicles
# 115         luxury vehicles
# 152         luxury vehicles
# 155         luxury vehicles
# 168         luxury vehicles
# 175     commercial vehicles
# 212   motorbikes   scooters
# 254     commercial vehicles
# 274     commercial vehicles
# 280     commercial vehicles
# 282        auto dealerships
# 291     commercial vehicles
# 301   motorbikes   scooters
# 338     commercial vehicles
# 358         luxury vehicles
# 399     commercial vehicles
# 426     commercial vehicles
# 464     commercial vehicles
# 541         luxury vehicles
# 551         luxury vehicles
# 569         luxury vehicles
# 581         luxury vehicles
# 592     commercial vehicles
# 610     commercial vehicles
# 650     commercial vehicles
# 654   motorbikes   scooters
# 657         luxury vehicles
# ...                     ...
# 5846    commercial vehicles
# 5853    commercial vehicles
# 5870        luxury vehicles
# 5888        luxury vehicles
# 5893    commercial vehicles
# 5900    commercial vehicles
# 5905        luxury vehicles
# 5921    commercial vehicles
# 5952    commercial vehicles
# 5982    commercial vehicles
# 6020    commercial vehicles
# 6031    commercial vehicles
# 6036       auto dealerships
# 6063    commercial vehicles
# 6081    commercial vehicles
# 6117  motorbikes   scooters
# 6128    commercial vehicles
# 6133    commercial vehicles
# 6137    commercial vehicles
# 6146    commercial vehicles
# 6152    commercial vehicles
# 6195  motorbikes   scooters
# 6203  motorbikes   scooters
# 6252  motorbikes   scooters
# 6261  motorbikes   scooters
# 6270  motorbikes   scooters
# 6280  motorbikes   scooters
# 6290  motorbikes   scooters
# 6300  motorbikes   scooters
# 6310  motorbikes   scooters
#
# [316 rows x 5 columns]

# %%
unclassified_predicted.to_csv('unclassified_predicted.csv')
